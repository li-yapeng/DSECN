# %% [markdown]
# ## CUB Dataset

# %% [markdown]
# ### DSECN

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_DSECN_pipeline.py --att_type 'clip' --seed 58 --train_dataset 'CUB' --use_DSE --use_HTE
# Out:
# <=============== Loading train data for CUB ===============>
# P:CUB|T:['CUB']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxonomy class names ===============>
#
# <=============== Starting training ===============>
# use_data:True | use_DSE:True | use_HTE:True
# DSECN(
#   (S2V): Sequential(
#     (0): Linear(in_features=512, out_features=1024, bias=True)
#     (1): Dropout(p=0.3, inplace=False)
#     (2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (3): ReLU()
#     (4): Linear(in_features=1024, out_features=1024, bias=True)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (7): ReLU()
#     (8): Linear(in_features=1024, out_features=2048, bias=True)
#     (9): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#     (10): ReLU()
#   )
# ...

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_DSECN_pipeline.py --att_type 'w2v' --seed 10 --train_dataset 'CUB' --use_DSE --use_HTE
# Out:
# <=============== Loading train data for CUB ===============>
# P:CUB|T:['CUB']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxonomy class names ===============>
#
# <=============== Starting training ===============>
# use_data:True | use_DSE:True | use_HTE:True
# DSECN(
#   (S2V): Sequential(
#     (0): Linear(in_features=300, out_features=1024, bias=True)
#     (1): Dropout(p=0.3, inplace=False)
#     (2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (3): ReLU()
#     (4): Linear(in_features=1024, out_features=1024, bias=True)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (7): ReLU()
#     (8): Linear(in_features=1024, out_features=2048, bias=True)
#     (9): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#     (10): ReLU()
#   )
# ...

# %% [markdown]
# ### Class Norm
# Class normalization for (continual)? generalized zero-shot learning. ICLR, 2021

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_CN_pipeline.py --att_type 'clip' --train_dataset 'CUB'
# Out:
# <=============== Loading train data for CUB ===============>
# P:CUB|T:['CUB']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxononmy class names ===============>
#
# <=============== Starting training ===============>
# Epoch:0|Loss:2.1587510108947754
# Epoch:1|Loss:1.8298540115356445
# Epoch:2|Loss:1.7782740592956543
# Epoch:3|Loss:1.6321213245391846
# Epoch:4|Loss:1.696915626525879
# Epoch:5|Loss:1.5856750011444092
# Epoch:6|Loss:1.4049707651138306
# Epoch:7|Loss:1.3510432243347168
# Epoch:8|Loss:1.3526923656463623
# Epoch:9|Loss:1.3604575395584106
# Epoch:10|Loss:1.3621625900268555
# Epoch:11|Loss:1.4844269752502441
# Epoch:12|Loss:1.3253995180130005
# Epoch:13|Loss:1.4096009731292725
# Epoch:14|Loss:1.4482303857803345
# Epoch:15|Loss:1.3740830421447754
# Epoch:16|Loss:1.3324096202850342
# Epoch:17|Loss:1.3603155612945557
# ...

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_CN_pipeline.py --att_type 'w2v' --train_dataset 'CUB'
# Out:
# <=============== Loading train data for CUB ===============>
# P:CUB|T:['CUB']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxononmy class names ===============>
#
# <=============== Starting training ===============>
# Epoch:0|Loss:2.23854923248291
# Epoch:1|Loss:1.818071722984314
# Epoch:2|Loss:1.5527245998382568
# Epoch:3|Loss:1.6335115432739258
# Epoch:4|Loss:1.4561868906021118
# Epoch:5|Loss:1.5830485820770264
# Epoch:6|Loss:1.402977705001831
# Epoch:7|Loss:1.414271593093872
# Epoch:8|Loss:1.334686279296875
# Epoch:9|Loss:1.5524934530258179
# Epoch:10|Loss:1.4279416799545288
# Epoch:11|Loss:1.3251527547836304
# Epoch:12|Loss:1.4068456888198853
# Epoch:13|Loss:1.413356065750122
# Epoch:14|Loss:1.5503734350204468
# Epoch:15|Loss:1.4581732749938965
# Epoch:16|Loss:1.3389475345611572
# Epoch:17|Loss:1.2320351600646973
# ...

# %% [markdown]
# ### Boost Class Norm by Integrating DSECN

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_CN_pipeline.py --att_type 'clip' --train_dataset 'CUB' --use_DSECN
# Out:
# <=============== Loading train data for CUB ===============>
# P:CUB|T:['CUB']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxononmy class names ===============>
#
# <=============== Starting training ===============>
# Epoch:0|Loss:2.97343111038208
# Epoch:1|Loss:2.2223422527313232
# Epoch:2|Loss:2.002946138381958
# Epoch:3|Loss:1.8222689628601074
# Epoch:4|Loss:1.7667114734649658
# Epoch:5|Loss:1.6194443702697754
# Epoch:6|Loss:1.6405304670333862
# Epoch:7|Loss:1.4905996322631836
# Epoch:8|Loss:1.474440574645996
# Epoch:9|Loss:1.5577691793441772
# Epoch:10|Loss:1.5033460855484009
# Epoch:11|Loss:1.3903844356536865
# Epoch:12|Loss:1.4882842302322388
# Epoch:13|Loss:1.3698337078094482
# Epoch:14|Loss:1.4488428831100464
# Epoch:15|Loss:1.3672449588775635
# Epoch:16|Loss:1.4871997833251953
# Epoch:17|Loss:1.4622247219085693
# ...

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_CN_pipeline.py --att_type 'w2v' --train_dataset 'CUB' --use_DSECN
# Out:
# <=============== Loading train data for CUB ===============>
# P:CUB|T:['CUB']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxononmy class names ===============>
#
# <=============== Starting training ===============>
# Epoch:0|Loss:5.191691875457764
# Epoch:1|Loss:2.852937698364258
# Epoch:2|Loss:2.4450860023498535
# Epoch:3|Loss:1.9136857986450195
# Epoch:4|Loss:1.8198153972625732
# Epoch:5|Loss:1.7324529886245728
# Epoch:6|Loss:1.816580891609192
# Epoch:7|Loss:1.6376893520355225
# Epoch:8|Loss:1.5541315078735352
# Epoch:9|Loss:1.5999295711517334
# Epoch:10|Loss:1.4215326309204102
# Epoch:11|Loss:1.3542232513427734
# Epoch:12|Loss:1.6128485202789307
# Epoch:13|Loss:1.4597030878067017
# Epoch:14|Loss:1.3506355285644531
# Epoch:15|Loss:1.4140229225158691
# Epoch:16|Loss:1.5349907875061035
# Epoch:17|Loss:1.3210582733154297
# ...

# %% [markdown]
# ## AWA2 Dataset

# %% [markdown]
# ### DSECN

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_DSECN_pipeline.py --att_type 'clip' --seed 58 --train_dataset 'AWA2' --use_DSE --use_HTE
# Out:
# <=============== Loading train data for AWA2 ===============>
# P:AWA2|T:['AWA2']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxonomy class names ===============>
#
# <=============== Starting training ===============>
# use_data:True | use_DSE:True | use_HTE:True
# DSECN(
#   (S2V): Sequential(
#     (0): Linear(in_features=512, out_features=1024, bias=True)
#     (1): Dropout(p=0.3, inplace=False)
#     (2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (3): ReLU()
#     (4): Linear(in_features=1024, out_features=1024, bias=True)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (7): ReLU()
#     (8): Linear(in_features=1024, out_features=2048, bias=True)
#     (9): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#     (10): ReLU()
#   )
# ...

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_DSECN_pipeline.py --att_type 'w2v' --seed 58 --train_dataset 'AWA2' --use_DSE --use_HTE
# Out:
# <=============== Loading train data for AWA2 ===============>
# P:AWA2|T:['AWA2']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxonomy class names ===============>
#
# <=============== Starting training ===============>
# use_data:True | use_DSE:True | use_HTE:True
# DSECN(
#   (S2V): Sequential(
#     (0): Linear(in_features=300, out_features=1024, bias=True)
#     (1): Dropout(p=0.3, inplace=False)
#     (2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (3): ReLU()
#     (4): Linear(in_features=1024, out_features=1024, bias=True)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (7): ReLU()
#     (8): Linear(in_features=1024, out_features=2048, bias=True)
#     (9): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#     (10): ReLU()
#   )
# ...

# %% [markdown]
# ### Class Norm
# Class normalization for (continual)? generalized zero-shot learning. ICLR, 2021

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_CN_pipeline.py --att_type 'clip' --train_dataset 'AWA2'
# Out:
# <=============== Loading train data for AWA2 ===============>
# P:AWA2|T:['AWA2']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxononmy class names ===============>
#
# <=============== Starting training ===============>
# Epoch:0|Loss:0.2485259622335434
# Epoch:1|Loss:0.20764769613742828
# Epoch:2|Loss:0.2061893790960312
# Epoch:3|Loss:0.2401273250579834
# Epoch:4|Loss:0.18662582337856293
# Epoch:5|Loss:0.20368987321853638
# Epoch:6|Loss:0.21596872806549072
# Epoch:7|Loss:0.22137954831123352
# Epoch:8|Loss:0.17328980565071106
# Epoch:9|Loss:0.2265506088733673
# Epoch:10|Loss:0.19444639980793
# Epoch:11|Loss:0.15707093477249146
# Epoch:12|Loss:0.19695408642292023
# Epoch:13|Loss:0.2179742455482483
# Epoch:14|Loss:0.1529826521873474
# Epoch:15|Loss:0.1908022165298462
# Epoch:16|Loss:0.15181082487106323
# ...

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_CN_pipeline.py --att_type 'w2v' --train_dataset 'AWA2'
# Out:
# <=============== Loading train data for AWA2 ===============>
# P:AWA2|T:['AWA2']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxononmy class names ===============>
#
# <=============== Starting training ===============>
# Epoch:0|Loss:0.23404137790203094
# Epoch:1|Loss:0.21493259072303772
# Epoch:2|Loss:0.14298951625823975
# Epoch:3|Loss:0.23364901542663574
# Epoch:4|Loss:0.2041480839252472
# Epoch:5|Loss:0.15925008058547974
# Epoch:6|Loss:0.14656037092208862
# Epoch:7|Loss:0.1727912425994873
# Epoch:8|Loss:0.2274465262889862
# Epoch:9|Loss:0.19095000624656677
# Epoch:10|Loss:0.20470380783081055
# Epoch:11|Loss:0.19058285653591156
# Epoch:12|Loss:0.1923455446958542
# Epoch:13|Loss:0.19604505598545074
# Epoch:14|Loss:0.24097609519958496
# Epoch:15|Loss:0.20604528486728668
# Epoch:16|Loss:0.1838916540145874
# ...

# %% [markdown]
# ### Boost Class Norm by Integrating DSECN

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_CN_pipeline.py --att_type 'clip' --train_dataset 'AWA2' --use_DSECN
# Out:
# <=============== Loading train data for AWA2 ===============>
# P:AWA2|T:['AWA2']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxononmy class names ===============>
#
# <=============== Starting training ===============>
# Epoch:0|Loss:0.3331970274448395
# Epoch:1|Loss:0.34608933329582214
# Epoch:2|Loss:0.32654812932014465
# Epoch:3|Loss:0.24545784294605255
# Epoch:4|Loss:0.24947567284107208
# Epoch:5|Loss:0.21860913932323456
# Epoch:6|Loss:0.21746785938739777
# Epoch:7|Loss:0.2275795340538025
# Epoch:8|Loss:0.22278675436973572
# Epoch:9|Loss:0.20556531846523285
# Epoch:10|Loss:0.18420758843421936
# Epoch:11|Loss:0.20442241430282593
# Epoch:12|Loss:0.19846989214420319
# Epoch:13|Loss:0.19908399879932404
# Epoch:14|Loss:0.20054563879966736
# Epoch:15|Loss:0.2333446741104126
# Epoch:16|Loss:0.25012829899787903
# ...

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_CN_pipeline.py --att_type 'w2v' --train_dataset 'AWA2' --use_DSECN
# Out:
# <=============== Loading train data for AWA2 ===============>
# P:AWA2|T:['AWA2']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxononmy class names ===============>
#
# <=============== Starting training ===============>
# Epoch:0|Loss:0.3846594989299774
# Epoch:1|Loss:0.22256968915462494
# Epoch:2|Loss:0.25501418113708496
# Epoch:3|Loss:0.22190135717391968
# Epoch:4|Loss:0.23640885949134827
# Epoch:5|Loss:0.2072175145149231
# Epoch:6|Loss:0.20897886157035828
# Epoch:7|Loss:0.2035229355096817
# Epoch:8|Loss:0.22850766777992249
# Epoch:9|Loss:0.21098625659942627
# Epoch:10|Loss:0.20235328376293182
# Epoch:11|Loss:0.2267458289861679
# Epoch:12|Loss:0.18971624970436096
# Epoch:13|Loss:0.23514114320278168
# Epoch:14|Loss:0.19664274156093597
# Epoch:15|Loss:0.23677217960357666
# Epoch:16|Loss:0.2554027736186981
# ...

# %% [markdown]
# ## SUN Dataset

# %% [markdown]
# ### DSECN

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_DSECN_pipeline.py --att_type 'clip' --seed 58 --train_dataset 'SUN' --use_DSE --use_HTE
# Out:
# <=============== Loading train data for SUN ===============>
# P:SUN|T:['SUN']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxonomy class names ===============>
#
# <=============== Starting training ===============>
# use_data:True | use_DSE:True | use_HTE:True
# DSECN(
#   (S2V): Sequential(
#     (0): Linear(in_features=512, out_features=1024, bias=True)
#     (1): Dropout(p=0.3, inplace=False)
#     (2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (3): ReLU()
#     (4): Linear(in_features=1024, out_features=1024, bias=True)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (7): ReLU()
#     (8): Linear(in_features=1024, out_features=2048, bias=True)
#     (9): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#     (10): ReLU()
#   )
# ...

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_DSECN_pipeline.py --att_type 'w2v' --seed 58 --train_dataset 'SUN' --use_DSE --use_HTE
# Out:
# <=============== Loading train data for SUN ===============>
# P:SUN|T:['SUN']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxonomy class names ===============>
#
# <=============== Starting training ===============>
# use_data:True | use_DSE:True | use_HTE:True
# DSECN(
#   (S2V): Sequential(
#     (0): Linear(in_features=300, out_features=1024, bias=True)
#     (1): Dropout(p=0.3, inplace=False)
#     (2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (3): ReLU()
#     (4): Linear(in_features=1024, out_features=1024, bias=True)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (7): ReLU()
#     (8): Linear(in_features=1024, out_features=2048, bias=True)
#     (9): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#     (10): ReLU()
#   )
# ...

# %% [markdown]
# ### Class Norm
# Class normalization for (continual)? generalized zero-shot learning. ICLR, 2021

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_CN_pipeline.py --att_type 'clip' --train_dataset 'SUN'
# Out:
# <=============== Loading train data for SUN ===============>
# P:SUN|T:['SUN']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxononmy class names ===============>
#
# <=============== Starting training ===============>
# Epoch:0|Loss:3.0483388900756836
# Epoch:1|Loss:2.783334255218506
# Epoch:2|Loss:2.4704537391662598
# Epoch:3|Loss:2.4042227268218994
# Epoch:4|Loss:1.8238599300384521
# Epoch:5|Loss:2.170196533203125
# Epoch:6|Loss:2.255297899246216
# Epoch:7|Loss:2.1412081718444824
# Epoch:8|Loss:1.777186632156372
# Epoch:9|Loss:1.9186079502105713
# Epoch:10|Loss:2.013701915740967
# Epoch:11|Loss:1.9266407489776611
# Epoch:12|Loss:2.0781705379486084
# Epoch:13|Loss:1.995134949684143
# Epoch:14|Loss:2.0249316692352295
# Epoch:15|Loss:1.8569154739379883
# Epoch:16|Loss:1.7157819271087646
# Epoch:17|Loss:1.934141755104065
# ...

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_CN_pipeline.py --att_type 'w2v' --train_dataset 'SUN'
# Out:
# <=============== Loading train data for SUN ===============>
# P:SUN|T:['SUN']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxononmy class names ===============>
#
# <=============== Starting training ===============>
# Epoch:0|Loss:3.3089606761932373
# Epoch:1|Loss:2.8664848804473877
# Epoch:2|Loss:2.460972309112549
# Epoch:3|Loss:2.1253774166107178
# Epoch:4|Loss:2.1361353397369385
# Epoch:5|Loss:2.157536506652832
# Epoch:6|Loss:2.0099871158599854
# Epoch:7|Loss:1.9470844268798828
# Epoch:8|Loss:1.8228498697280884
# Epoch:9|Loss:1.6711772680282593
# Epoch:10|Loss:1.8640880584716797
# Epoch:11|Loss:1.8525997400283813
# Epoch:12|Loss:2.358802318572998
# Epoch:13|Loss:1.864886999130249
# Epoch:14|Loss:1.7876876592636108
# Epoch:15|Loss:1.9898507595062256
# Epoch:16|Loss:1.8710753917694092
# Epoch:17|Loss:1.5733119249343872
# ...

# %% [markdown]
# ### Boost Class Norm by Integrating DSECN

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_CN_pipeline.py --att_type 'clip' --train_dataset 'SUN' --use_DSECN
# Out:
# <=============== Loading train data for SUN ===============>
# P:SUN|T:['SUN']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxononmy class names ===============>
#
# <=============== Starting training ===============>
# Epoch:0|Loss:3.787519931793213
# Epoch:1|Loss:3.0983593463897705
# Epoch:2|Loss:2.760587453842163
# Epoch:3|Loss:2.551194190979004
# Epoch:4|Loss:2.6272709369659424
# Epoch:5|Loss:2.177776575088501
# Epoch:6|Loss:2.320856809616089
# Epoch:7|Loss:1.9054347276687622
# Epoch:8|Loss:2.09421706199646
# Epoch:9|Loss:1.9144713878631592
# Epoch:10|Loss:1.857204794883728
# Epoch:11|Loss:1.8860394954681396
# Epoch:12|Loss:1.8024462461471558
# Epoch:13|Loss:1.841915488243103
# Epoch:14|Loss:1.9745442867279053
# Epoch:15|Loss:1.9739779233932495
# Epoch:16|Loss:1.9847712516784668
# Epoch:17|Loss:1.9647544622421265
# ...

# %%
# !CUDA_VISIBLE_DEVICES=7 python train_CN_pipeline.py --att_type 'w2v' --train_dataset 'SUN' --use_DSECN
# Out:
# <=============== Loading train data for SUN ===============>
# P:SUN|T:['SUN']
# <=============== Preprocessing ===============>
# <=============== Loading semantics data from External base class names ===============>
# <=============== Loading semantics data from hierarchy taxononmy class names ===============>
#
# <=============== Starting training ===============>
# Epoch:0|Loss:4.66459321975708
# Epoch:1|Loss:3.7151827812194824
# Epoch:2|Loss:3.1805503368377686
# Epoch:3|Loss:3.013188362121582
# Epoch:4|Loss:2.666048765182495
# Epoch:5|Loss:2.592646837234497
# Epoch:6|Loss:2.5131208896636963
# Epoch:7|Loss:2.3619132041931152
# Epoch:8|Loss:2.276618480682373
# Epoch:9|Loss:2.4023070335388184
# Epoch:10|Loss:2.0121936798095703
# Epoch:11|Loss:2.1425201892852783
# Epoch:12|Loss:1.935467004776001
# Epoch:13|Loss:2.2264387607574463
# Epoch:14|Loss:2.0716447830200195
# Epoch:15|Loss:1.900823712348938
# Epoch:16|Loss:1.949875831604004
# Epoch:17|Loss:1.97227942943573
# ...

# %% [markdown]
# ###
